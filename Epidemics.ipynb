# %%
#we set the initial set of infected nodes as 1% of the overall population, and assign a threshold of 0.25 to all the nodes.
import networkx as nx
import ndlib
import ndlib.models.ModelConfig as mc
import ndlib.models.epidemics as ep
import pandas as pd
   
# Network topology
G

df = pd.read_excel('C:/Users/Priyam/Documents/DM_CW/highest_nodes.xlsx')

# Creating a graph from a pandas dataframe
G = nx.from_pandas_edgelist(df, 'Source', 'Target', 'Weights')
for index, row in df.iterrows():
    G.add_edge(row['Source'], row['Target'])    
    
    
# Model selection
model = ep.ThresholdModel(G)


# Model Configuration
config = mc.Configuration()
config.add_model_parameter('fraction_infected', 0.1)

# Setting node parameters
threshold = 0.1
for i in G.nodes():
    config.add_node_configuration("threshold", i, threshold)

model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(200)
iterations
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:05<00:00, 38.52it/s]
# [{'iteration': 0,
#   'status': {7222: 0,
#    19829: 0,
#    8948: 0,
#    8960: 0,
#    8954: 0,
#    16455: 0,
#    15219: 0,
#    11136: 0,
#    11142: 0,
#    20862: 0,
#    10922: 0,
#    15783: 0,
#    18846: 0,
#    9690: 0,
#    7238: 0,
#    20807: 0,
#    9556: 0,
#    17780: 0,
#    21475: 1,
#    9020: 0,
#    8058: 0,
#    17582: 1,
#    17629: 0,
#    12999: 0,
#    12689: 0,
#    12381: 0,
#    14273: 0,
#    15559: 0,
#    18757: 0,
#    13978: 0,
#    20283: 1,
#    17615: 0,
#    21132: 0,
#    17278: 0,
#    7522: 0,
#    18391: 0,
#    17594: 0,
#    19325: 0,
#    7654: 0,
#    17759: 0,
#    17837: 0,
#    15791: 0,
#    10785: 0,
#    18361: 0,
#    7606: 1,
#    16775: 0,
#    12013: 1,
#    12745: 0,
#    17587: 0,
#    16004: 0,
#    11515: 0,
#    12877: 1,
#    8679: 1,
#    18535: 1,
#    16732: 0,
#    9968: 0,
#    8472: 0,
# ...

# %%
import networkx as nx
import ndlib
import ndlib.models.ModelConfig as mc
import ndlib.models.epidemics as ep
import pandas as pd

# Network topology
G
###########
# Reading in the data for the Inviters and Invitees from the the Bloomberg Chat Data
df = pd.read_excel('C:/Users/Priyam/Documents/DM_CW/lowest_nodes.xlsx')#C:/Users/Priyam/Documents/
#df = csv.reader(open("C:/Users/Priyam/Documents/glaston_AD_edges_CD.csv"), delimiter=" ")

# Creating a graph from a pandas dataframe
G = nx.from_pandas_edgelist(df, 'Source', 'Target', 'Weights')
for index, row in df.iterrows():
    G.add_edge(row['Source'], row['Target'])    
    
    
# Model selection
model = ep.ThresholdModel(G)


# Model Configuration
config = mc.Configuration()
config.add_model_parameter('fraction_infected', 0.1)

# Setting node parameters
threshold = 0.5
for i in G.nodes():
    config.add_node_configuration("threshold", i, threshold)

model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(200)
iterations
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 33424.74it/s]
# [{'iteration': 0,
#   'status': {1530: 0, 13407: 1},
#   'node_count': {0: 1, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 1,
#   'status': {1530: 1},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: -1, 1: 1}},
#  {'iteration': 2,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 3,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 4,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 5,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 6,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 7,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
# ...

# %%
import networkx as nx
import ndlib
import ndlib.models.ModelConfig as mc
import ndlib.models.epidemics as ep
import pandas as pd
# Network topology
G
###########
# Reading in the data for the Inviters and Invitees from the the Bloomberg Chat Data
df = pd.read_excel('C:/Users/Priyam/Documents/DM_CW/average_nodes.xlsx')#C:/Users/Priyam/Documents/
#df = csv.reader(open("C:/Users/Priyam/Documents/glaston_AD_edges_CD.csv"), delimiter=" ")

# Creating a graph from a pandas dataframe
G = nx.from_pandas_edgelist(df, 'Source', 'Target', 'Weights')
for index, row in df.iterrows():
    G.add_edge(row['Source'], row['Target'])    
    
    
# Model selection
model = ep.ThresholdModel(G)


# Model Configuration
config = mc.Configuration()
config.add_model_parameter('fraction_infected', 0.1)

# Setting node parameters
threshold = 0.5
for i in G.nodes():
    config.add_node_configuration("threshold", i, threshold)

model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(200)
iterations
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 15424.49it/s]
# [{'iteration': 0,
#   'status': {1691: 0, 6285: 0, 4071: 0, 8537: 0, 8012: 0, 7522: 1},
#   'node_count': {0: 5, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 1,
#   'status': {},
#   'node_count': {0: 5, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 2,
#   'status': {},
#   'node_count': {0: 5, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 3,
#   'status': {},
#   'node_count': {0: 5, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 4,
#   'status': {},
#   'node_count': {0: 5, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 5,
#   'status': {},
#   'node_count': {0: 5, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 6,
#   'status': {},
#   'node_count': {0: 5, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 7,
#   'status': {},
#   'node_count': {0: 5, 1: 1},
# ...

# %%
import networkx as nx
import ndlib
import ndlib.models.ModelConfig as mc
import ndlib.models.epidemics as ep
import pandas as pd
# Network topology
G
###########
# Reading in the data for the Inviters and Invitees from the the Bloomberg Chat Data
df = pd.read_excel('C:/Users/Priyam/Documents/DM_CW/Additional_node1.xlsx')#C:/Users/Priyam/Documents/
#df = csv.reader(open("C:/Users/Priyam/Documents/glaston_AD_edges_CD.csv"), delimiter=" ")

# Creating a graph from a pandas dataframe
G = nx.from_pandas_edgelist(df, 'Source', 'Target', 'Weights')
for index, row in df.iterrows():
    G.add_edge(row['Source'], row['Target'])    
    
    
# Model selection
model = ep.ThresholdModel(G)


# Model Configuration
config = mc.Configuration()
config.add_model_parameter('fraction_infected', 0.1)

# Setting node parameters
threshold = 0.75
for i in G.nodes():
    config.add_node_configuration("threshold", i, threshold)

model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(200)
iterations
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 485.50it/s]
# [{'iteration': 0,
#   'status': {20862: 0,
#    21444: 1,
#    21167: 0,
#    21005: 0,
#    21388: 0,
#    21166: 1,
#    20877: 0,
#    20865: 0,
#    20869: 0,
#    21132: 0,
#    21503: 0,
#    21458: 0,
#    21135: 0,
#    20873: 0,
#    20947: 1,
#    20867: 0,
#    20870: 1,
#    21457: 0,
#    20863: 0,
#    21308: 0,
#    5376: 0,
#    21168: 0,
#    21456: 0,
#    21325: 0,
#    20888: 0,
#    21083: 0,
#    3868: 0,
#    5613: 0,
#    7222: 0,
#    10785: 0,
#    3753: 1,
#    18361: 0,
#    7130: 0,
#    20283: 0,
#    2591: 0,
#    19325: 0,
#    7654: 0,
#    5460: 0,
#    5619: 0,
#    1503: 0,
#    2800: 0,
#    12370: 0,
#    9511: 0,
#    6473: 0,
#    3115: 0,
#    15791: 0,
#    1491: 1,
#    16775: 1,
#    8804: 0,
#    15212: 0,
#    2590: 0,
#    10803: 0,
#    906: 0,
#    15173: 0,
#    10800: 0,
#    9358: 0,
#    17152: 0,
#    2588: 0,
# ...

# %%
import networkx as nx
import ndlib
import ndlib.models.ModelConfig as mc
import ndlib.models.epidemics as ep
import pandas as pd
# Network topology
G
###########
# Reading in the data for the Inviters and Invitees from the the Bloomberg Chat Data
df = pd.read_excel('C:/Users/Priyam/Documents/DM_CW/Additional_node2.xlsx')#C:/Users/Priyam/Documents/
#df = csv.reader(open("C:/Users/Priyam/Documents/glaston_AD_edges_CD.csv"), delimiter=" ")

# Creating a graph from a pandas dataframe
G = nx.from_pandas_edgelist(df, 'Source', 'Target', 'Weights')
for index, row in df.iterrows():
    G.add_edge(row['Source'], row['Target'])    
    
    
# Model selection
model = ep.ThresholdModel(G)


# Model Configuration
config = mc.Configuration()
config.add_model_parameter('fraction_infected', 0.1)

# Setting node parameters
threshold = 0.1
for i in G.nodes():
    config.add_node_configuration("threshold", i, threshold)

model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(200)
iterations
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 40104.26it/s]
# [{'iteration': 0,
#   'status': {7222: 0, 15219: 1},
#   'node_count': {0: 1, 1: 1},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 1,
#   'status': {7222: 1},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: -1, 1: 1}},
#  {'iteration': 2,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 3,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 4,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 5,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 6,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
#  {'iteration': 7,
#   'status': {},
#   'node_count': {0: 0, 1: 2},
#   'status_delta': {0: 0, 1: 0}},
# ...
